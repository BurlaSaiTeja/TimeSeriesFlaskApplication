# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Store1.csv", encoding='latin')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11-09-2013  11-12-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  11-09-2013  11-12-2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10-11-2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10-11-2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country City_Code State_Code  \
# 0      Claire Gute   Consumer  United States      C259        S16
# 1      Claire Gute   Consumer  United States      C259        S16
# 2  Darrin Van Huff  Corporate  United States       C64        S04
# 3   Sean O'Donnell   Consumer  United States      C150        S09
# 4   Sean O'Donnell   Consumer  United States      C150        S09
#
#    Postal Code       Product ID         Category Sub-Category  \
# 0        42420  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  FUR-CH-10000454        Furniture       Chairs
# 2        90036  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  FUR-TA-10000577        Furniture       Tables
# 4        33311  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode        22
# Customer ID       0
# Customer Name     0
# Segment           9
# Country           6
# City_Code         0
# State_Code        0
# Postal Code       0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
#Removing null values

# %%
import statistics

# %%
df['Ship Mode'].value_counts().idxmax()
# Out:
# 'Standard Class'

# %%
#Since there are only 22 values missing out of 9994 we can just make use of idxmax() function 
#to get the value that is most frequently occuring in the dataset and use that value to fill the null values.

# %%
df['Ship Mode'] = df['Ship Mode'].fillna('Standard Class')

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          9
# Country          6
# City_Code        0
# State_Code       0
# Postal Code      0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.Country.unique()
# Out:
# array(['United States', nan], dtype=object)

# %%
df['Country'] = df['Country'].fillna('United States')

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          9
# Country          0
# City_Code        0
# State_Code       0
# Postal Code      0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#Since there are very few rows where we have null values for segment we can just delete them
#as filling them with values with mean median or mode would not make sense

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City_Code        0
# State_Code       0
# Postal Code      0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.shape[0]
# Out:
# 9985

# %%
#So we finally have 9985 rows in our dataset that we can work with.

# %%
df.describe()
# Out:
#             Row ID  Postal Code         Sales     Quantity     Discount  \
# count  9985.000000   9985.00000   9985.000000  9985.000000  9985.000000
# mean   4993.896545  55182.79359    229.636100     3.789685     0.156183
# std    2883.894709  32060.89504    622.927104     2.225074     0.206477
# min       1.000000   1040.00000      0.444000     1.000000     0.000000
# 25%    2497.000000  23223.00000     17.280000     2.000000     0.000000
# 50%    4993.000000  56301.00000     54.500000     3.000000     0.200000
# 75%    7489.000000  90008.00000    209.940000     5.000000     0.200000
# max    9994.000000  99301.00000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9985.000000
# mean     28.587722
# std     234.183523
# min   -6599.978000
# 25%       1.731000
# 50%       8.671500
# 75%      29.364000
# max    8399.976000

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City_Code         object
# State_Code        object
# Postal Code        int64
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
#we can see that order date and ship date are of the type object 
#we need to convert them into datetime for us to get any inferences from those rows
#before we do that lets combine all the other tables we have so we can print better results for better understanding

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df['Ship_Date'] = df['Ship_Date'].str.replace('-','/') 
df['Ship_Date']
# Out:
# 0       11/12/2013
# 1       11/12/2013
# 2        6/17/2013
# 3       10/18/2012
# 4       10/18/2012
#            ...
# 9989     1/24/2011
# 9990    03/04/2014
# 9991    03/04/2014
# 9992    03/04/2014
# 9993    05/10/2014
# Name: Ship_Date, Length: 9985, dtype: object

# %%
df['Order_Date'] = df['Order_Date'].str.replace('-','/') 
df['Order_Date']
# Out:
# 0       11/09/2013
# 1       11/09/2013
# 2        6/13/2013
# 3       10/11/2012
# 4       10/11/2012
#            ...
# 9989     1/22/2011
# 9990     2/27/2014
# 9991     2/27/2014
# 9992     2/27/2014
# 9993    05/05/2014
# Name: Order_Date, Length: 9985, dtype: object

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9985 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9985 non-null   int64
#  1   Order_ID       9985 non-null   object
#  2   Order_Date     9985 non-null   datetime64[ns]
#  3   Ship_Date      9985 non-null   datetime64[ns]
#  4   Ship_Mode      9985 non-null   object
#  5   Customer_ID    9985 non-null   object
#  6   Customer_Name  9985 non-null   object
#  7   Segment        9985 non-null   object
#  8   Country        9985 non-null   object
#  9   City_Code      9985 non-null   object
#  10  State_Code     9985 non-null   object
#  11  Postal_Code    9985 non-null   int64
#  12  Product_ID     9985 non-null   object
#  13  Category       9985 non-null   object
#  14  Sub-Category   9985 non-null   object
#  15  Product_Name   9985 non-null   object
#  16  Sales          9985 non-null   float64
#  17  Quantity       9985 non-null   int64
#  18  Discount       9985 non-null   float64
#  19  Profit         9985 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(12)
# memory usage: 1.6+ MB

# %%
df.head(10)
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 5       6  CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 6       7  CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 7       8  CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 8       9  CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 9      10  CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
#
#      Customer_Name    Segment        Country City_Code State_Code  \
# 0      Claire Gute   Consumer  United States      C259        S16
# 1      Claire Gute   Consumer  United States      C259        S16
# 2  Darrin Van Huff  Corporate  United States       C64        S04
# 3   Sean O'Donnell   Consumer  United States      C150        S09
# 4   Sean O'Donnell   Consumer  United States      C150        S09
# 5  Brosina Hoffman   Consumer  United States       C64        S04
# 6  Brosina Hoffman   Consumer  United States       C64        S04
# 7  Brosina Hoffman   Consumer  United States       C64        S04
# 8  Brosina Hoffman   Consumer  United States       C64        S04
# 9  Brosina Hoffman   Consumer  United States       C64        S04
#
#    Postal_Code       Product_ID         Category Sub-Category  \
# 0        42420  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  FUR-CH-10000454        Furniture       Chairs
# 2        90036  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  FUR-TA-10000577        Furniture       Tables
# 4        33311  OFF-ST-10000760  Office Supplies      Storage
# 5        90032  FUR-FU-10001487        Furniture  Furnishings
# 6        90032  OFF-AR-10002833  Office Supplies          Art
# 7        90032  TEC-PH-10002275       Technology       Phones
# 8        90032  OFF-BI-10003910  Office Supplies      Binders
# 9        90032  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product_Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                         Newell 322    7.2800         4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520         6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040         3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700

# %%
#Getting duration from order date to ship date
df['Duration'] = df['Ship_Date'] - df['Order_Date']
df
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country City_Code  ...  \
# 0       CG-12520       Claire Gute   Consumer  United States      C259  ...
# 1       CG-12520       Claire Gute   Consumer  United States      C259  ...
# 2       DV-13045   Darrin Van Huff  Corporate  United States       C64  ...
# 3       SO-20335    Sean O'Donnell   Consumer  United States      C150  ...
# 4       SO-20335    Sean O'Donnell   Consumer  United States      C150  ...
# ...          ...               ...        ...            ...       ...  ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States      C160  ...
# 9990    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 9991    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 9992    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 9993    CC-12220      Chris Cortes   Consumer  United States      C108  ...
#
#      Postal_Code       Product_ID         Category Sub-Category  \
# 0          42420  FUR-BO-10001798        Furniture    Bookcases
# 1          42420  FUR-CH-10000454        Furniture       Chairs
# 2          90036  OFF-LA-10000240  Office Supplies       Labels
# 3          33311  FUR-TA-10000577        Furniture       Tables
# 4          33311  OFF-ST-10000760  Office Supplies      Storage
# ...          ...              ...              ...          ...
# 9989       33180  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627  TEC-PH-10003645       Technology       Phones
# 9992       92627  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product_Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit  Duration
# 0         0.00   41.9136    3 days
# 1         0.00  219.5820    3 days
# 2         0.00    6.8714    4 days
# 3         0.45 -383.0310    7 days
# 4         0.20    2.5164    7 days
# ...        ...       ...       ...
# 9989      0.20    4.1028    2 days
# 9990      0.00   15.6332    5 days
# 9991      0.20   19.3932    5 days
# 9992      0.00   13.3200    5 days
# 9993      0.00   72.9480    5 days
#
# [9985 rows x 21 columns]

# %%
dfCity = pd.read_excel('City_Master_P.xlsx' )
dfCity.head()
# Out:
#   City_Code   City_Name
# 0       C01      Auburn
# 1       C02     Decatur
# 2       C03    Florence
# 3       C04      Hoover
# 4       C05  Huntsville

# %%
df1 = pd.merge(df,dfCity,how = 'inner')
df1.head(10)
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     539  CA-2012-134894 2012-12-07 2012-12-11  Standard Class    DK-12985
# 3     540  CA-2012-134894 2012-12-07 2012-12-11  Standard Class    DK-12985
# 4     997  CA-2012-162537 2012-10-28 2012-11-03  Standard Class    RD-19585
# 5     998  CA-2012-162537 2012-10-28 2012-11-03  Standard Class    RD-19585
# 6     999  CA-2012-162537 2012-10-28 2012-11-03  Standard Class    RD-19585
# 7    1000  CA-2012-162537 2012-10-28 2012-11-03  Standard Class    RD-19585
# 8    1867  CA-2014-118857 2014-04-16 2014-04-19     First Class    AH-10075
# 9    2322  CA-2012-109470 2012-12-31 2013-01-03    Second Class    KC-16255
#
#     Customer_Name    Segment        Country City_Code  ...       Product_ID  \
# 0     Claire Gute   Consumer  United States      C259  ...  FUR-BO-10001798
# 1     Claire Gute   Consumer  United States      C259  ...  FUR-CH-10000454
# 2  Darren Koutras   Consumer  United States      C259  ...  OFF-AP-10001271
# 3  Darren Koutras   Consumer  United States      C259  ...  FUR-CH-10002647
# 4        Rob Dowd   Consumer  United States      C259  ...  OFF-EN-10003862
# 5        Rob Dowd   Consumer  United States      C259  ...  OFF-ST-10004258
# 6        Rob Dowd   Consumer  United States      C259  ...  FUR-FU-10002885
# 7        Rob Dowd   Consumer  United States      C259  ...  FUR-FU-10001918
# 8       Adam Hart  Corporate  United States      C259  ...  FUR-FU-10004460
# 9  Karen Carlisle  Corporate  United States      C259  ...  OFF-BI-10004492
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies   Appliances
# 3        Furniture       Chairs
# 4  Office Supplies    Envelopes
# 5  Office Supplies      Storage
# 6        Furniture  Furnishings
# 7        Furniture  Furnishings
# 8        Furniture  Furnishings
# 9  Office Supplies      Binders
#
#                                         Product_Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
# 2    Eureka The Boss Cordless Rechargeable Stick Vac  152.94        3
# 3         Situations Contoured Folding Chairs, 4/Set  283.92        4
# 4                 Laser & Ink Jet Business Envelopes   10.67        1
# 5                         Portable Personal File Box   36.63        3
# 6              Magna Visual Magnetic Picture Hangers   24.10        5
# 7  C-Line Cubicle Keepers Polyproplyene Holder Wi...   33.11        7
# 8                 Howard Miller 12" Round Wall Clock  196.45        5
# 9                                    Tuf-Vin Binders   94.74        3
#
#    Discount    Profit  Duration  City_Name
# 0       0.0   41.9136    3 days  Henderson
# 1       0.0  219.5820    3 days  Henderson
# 2       0.0   41.2938    4 days  Henderson
# 3       0.0   70.9800    4 days  Henderson
# 4       0.0    4.9082    6 days  Henderson
# 5       0.0    9.8901    6 days  Henderson
# 6       0.0    9.1580    6 days  Henderson
# 7       0.0   12.9129    6 days  Henderson
# 8       0.0   70.7220    3 days  Henderson
# 9       0.0   44.5278    3 days  Henderson
#
# [10 rows x 22 columns]

# %%
df1.sort_values('Row_ID')
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 51         3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 798        4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 799        5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 6643    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 7107    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 7108    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 7109    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 8297    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country City_Code  ...  \
# 0       CG-12520       Claire Gute   Consumer  United States      C259  ...
# 1       CG-12520       Claire Gute   Consumer  United States      C259  ...
# 51      DV-13045   Darrin Van Huff  Corporate  United States       C64  ...
# 798     SO-20335    Sean O'Donnell   Consumer  United States      C150  ...
# 799     SO-20335    Sean O'Donnell   Consumer  United States      C150  ...
# ...          ...               ...        ...            ...       ...  ...
# 6643    TB-21400  Tom Boeckenhauer   Consumer  United States      C160  ...
# 7107    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 7108    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 7109    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 8297    CC-12220      Chris Cortes   Consumer  United States      C108  ...
#
#            Product_ID         Category Sub-Category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 51    OFF-LA-10000240  Office Supplies       Labels
# 798   FUR-TA-10000577        Furniture       Tables
# 799   OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 6643  FUR-FU-10001889        Furniture  Furnishings
# 7107  FUR-FU-10000747        Furniture  Furnishings
# 7108  TEC-PH-10003645       Technology       Phones
# 7109  OFF-PA-10004041  Office Supplies        Paper
# 8297  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product_Name     Sales Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600        2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 51    Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 798       Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 799                      Eldon Fold 'N Roll Cart System   22.3680        2
# ...                                                 ...       ...      ...
# 6643                             Ultra Door Pull Handle   25.2480        3
# 7107  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600        2
# 7108                              Aastra 57i VoIP phone  258.5760        2
# 7109  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000        4
# 8297  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600        2
#
#       Discount    Profit  Duration        City_Name
# 0         0.00   41.9136    3 days        Henderson
# 1         0.00  219.5820    3 days        Henderson
# 51        0.00    6.8714    4 days      Los Angeles
# 798       0.45 -383.0310    7 days  Fort Lauderdale
# 799       0.20    2.5164    7 days  Fort Lauderdale
# ...        ...       ...       ...              ...
# 6643      0.20    4.1028    2 days            Miami
# 7107      0.00   15.6332    5 days       Costa Mesa
# 7108      0.20   19.3932    5 days       Costa Mesa
# 7109      0.00   13.3200    5 days       Costa Mesa
# 8297      0.00   72.9480    5 days      Westminster
#
# [9985 rows x 22 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9985 entries, 0 to 9984
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9985 non-null   int64
#  1   Order_ID       9985 non-null   object
#  2   Order_Date     9985 non-null   datetime64[ns]
#  3   Ship_Date      9985 non-null   datetime64[ns]
#  4   Ship_Mode      9985 non-null   object
#  5   Customer_ID    9985 non-null   object
#  6   Customer_Name  9985 non-null   object
#  7   Segment        9985 non-null   object
#  8   Country        9985 non-null   object
#  9   City_Code      9985 non-null   object
#  10  State_Code     9985 non-null   object
#  11  Postal_Code    9985 non-null   int64
#  12  Product_ID     9985 non-null   object
#  13  Category       9985 non-null   object
#  14  Sub-Category   9985 non-null   object
#  15  Product_Name   9985 non-null   object
#  16  Sales          9985 non-null   float64
#  17  Quantity       9985 non-null   int64
#  18  Discount       9985 non-null   float64
#  19  Profit         9985 non-null   float64
#  20  Duration       9985 non-null   timedelta64[ns]
#  21  City_Name      9985 non-null   object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13), timedelta64[ns](1)
# memory usage: 1.8+ MB

# %%
dfState = pd.read_excel('State_Master.xlsx' )
dfState.head()
# Out:
#   State_Code       State
# 0        S01     Alabama
# 1        S02     Arizona
# 2        S03    Arkansas
# 3        S04  California
# 4        S05    Colorado

# %%
dfm = pd.merge(df1,dfState,how = 'inner')
dfm.head(5)
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     539  CA-2012-134894 2012-12-07 2012-12-11  Standard Class    DK-12985
# 3     540  CA-2012-134894 2012-12-07 2012-12-11  Standard Class    DK-12985
# 4     997  CA-2012-162537 2012-10-28 2012-11-03  Standard Class    RD-19585
#
#     Customer_Name   Segment        Country City_Code  ...         Category  \
# 0     Claire Gute  Consumer  United States      C259  ...        Furniture
# 1     Claire Gute  Consumer  United States      C259  ...        Furniture
# 2  Darren Koutras  Consumer  United States      C259  ...  Office Supplies
# 3  Darren Koutras  Consumer  United States      C259  ...        Furniture
# 4        Rob Dowd  Consumer  United States      C259  ...  Office Supplies
#
#    Sub-Category                                       Product_Name   Sales  \
# 0     Bookcases                  Bush Somerset Collection Bookcase  261.96
# 1        Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2    Appliances    Eureka The Boss Cordless Rechargeable Stick Vac  152.94
# 3        Chairs         Situations Contoured Folding Chairs, 4/Set  283.92
# 4     Envelopes                 Laser & Ink Jet Business Envelopes   10.67
#
#   Quantity Discount    Profit  Duration  City_Name     State
# 0        2      0.0   41.9136    3 days  Henderson  Kentucky
# 1        3      0.0  219.5820    3 days  Henderson  Kentucky
# 2        3      0.0   41.2938    4 days  Henderson  Kentucky
# 3        4      0.0   70.9800    4 days  Henderson  Kentucky
# 4        1      0.0    4.9082    6 days  Henderson  Kentucky
#
# [5 rows x 23 columns]

# %%
dfm.sort_values('Row_ID')
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 178        3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 2176       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 2177       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 2316    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 1811    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 1812    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 1813    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 1983    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country City_Code  ...  \
# 0       CG-12520       Claire Gute   Consumer  United States      C259  ...
# 1       CG-12520       Claire Gute   Consumer  United States      C259  ...
# 178     DV-13045   Darrin Van Huff  Corporate  United States       C64  ...
# 2176    SO-20335    Sean O'Donnell   Consumer  United States      C150  ...
# 2177    SO-20335    Sean O'Donnell   Consumer  United States      C150  ...
# ...          ...               ...        ...            ...       ...  ...
# 2316    TB-21400  Tom Boeckenhauer   Consumer  United States      C160  ...
# 1811    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 1812    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 1813    DB-13060       Dave Brooks   Consumer  United States       C43  ...
# 1983    CC-12220      Chris Cortes   Consumer  United States      C108  ...
#
#              Category  Sub-Category  \
# 0           Furniture     Bookcases
# 1           Furniture        Chairs
# 178   Office Supplies        Labels
# 2176        Furniture        Tables
# 2177  Office Supplies       Storage
# ...               ...           ...
# 2316        Furniture   Furnishings
# 1811        Furniture   Furnishings
# 1812       Technology        Phones
# 1813  Office Supplies         Paper
# 1983  Office Supplies    Appliances
#
#                                            Product_Name     Sales Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600        2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 178   Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 2176      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 2177                     Eldon Fold 'N Roll Cart System   22.3680        2
# ...                                                 ...       ...      ...
# 2316                             Ultra Door Pull Handle   25.2480        3
# 1811  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600        2
# 1812                              Aastra 57i VoIP phone  258.5760        2
# 1813  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000        4
# 1983  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600        2
#
#      Discount    Profit  Duration        City_Name       State
# 0        0.00   41.9136    3 days        Henderson    Kentucky
# 1        0.00  219.5820    3 days        Henderson    Kentucky
# 178      0.00    6.8714    4 days      Los Angeles  California
# 2176     0.45 -383.0310    7 days  Fort Lauderdale     Florida
# 2177     0.20    2.5164    7 days  Fort Lauderdale     Florida
# ...       ...       ...       ...              ...         ...
# 2316     0.20    4.1028    2 days            Miami     Florida
# 1811     0.00   15.6332    5 days       Costa Mesa  California
# 1812     0.20   19.3932    5 days       Costa Mesa  California
# 1813     0.00   13.3200    5 days       Costa Mesa  California
# 1983     0.00   72.9480    5 days      Westminster  California
#
# [9985 rows x 23 columns]

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9985 entries, 0 to 9984
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9985 non-null   int64
#  1   Order_ID       9985 non-null   object
#  2   Order_Date     9985 non-null   datetime64[ns]
#  3   Ship_Date      9985 non-null   datetime64[ns]
#  4   Ship_Mode      9985 non-null   object
#  5   Customer_ID    9985 non-null   object
#  6   Customer_Name  9985 non-null   object
#  7   Segment        9985 non-null   object
#  8   Country        9985 non-null   object
#  9   City_Code      9985 non-null   object
#  10  State_Code     9985 non-null   object
#  11  Postal_Code    9985 non-null   int64
#  12  Product_ID     9985 non-null   object
#  13  Category       9985 non-null   object
#  14  Sub-Category   9985 non-null   object
#  15  Product_Name   9985 non-null   object
#  16  Sales          9985 non-null   float64
#  17  Quantity       9985 non-null   int64
#  18  Discount       9985 non-null   float64
#  19  Profit         9985 non-null   float64
#  20  Duration       9985 non-null   timedelta64[ns]
#  21  City_Name      9985 non-null   object
#  22  State          9985 non-null   object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(14), timedelta64[ns](1)
# memory usage: 1.8+ MB

# %%
#Mean duration for each city and state
dfm.groupby(['State','City_Name'], as_index = False)['Duration'].mean()
# Out:
#          State   City_Name                  Duration
# 0      Alabama      Auburn           4 days 04:00:00
# 1      Alabama     Decatur 5 days 14:46:09.230769230
# 2      Alabama    Florence           2 days 19:12:00
# 3      Alabama      Hoover           3 days 12:00:00
# 4      Alabama  Huntsville           3 days 21:36:00
# ..         ...         ...                       ...
# 599  Wisconsin    Superior           5 days 00:00:00
# 600  Wisconsin    Waukesha           7 days 00:00:00
# 601  Wisconsin      Wausau           5 days 00:00:00
# 602  Wisconsin  West Allis           5 days 00:00:00
# 603    Wyoming    Cheyenne           5 days 00:00:00
#
# [604 rows x 3 columns]

# %%
#Max Sales for each city and state
Max_Sales = dfm.groupby(['State','City_Name'], as_index = False)['Sales'].sum()
Max_Sales
# Out:
#          State   City_Name     Sales
# 0      Alabama      Auburn  1766.830
# 1      Alabama     Decatur  3374.820
# 2      Alabama    Florence  1997.350
# 3      Alabama      Hoover   525.850
# 4      Alabama  Huntsville  2484.370
# ..         ...         ...       ...
# 599  Wisconsin    Superior  1299.730
# 600  Wisconsin    Waukesha    54.500
# 601  Wisconsin      Wausau   317.480
# 602  Wisconsin  West Allis   250.480
# 603    Wyoming    Cheyenne  1603.136
#
# [604 rows x 3 columns]

# %%
Max_Sales.max()
# Out:
# State           Wyoming
# City_Name          Yuma
# Sales        256368.161
# dtype: object

# %%
Max_Sales.min()
# Out:
# State         Alabama
# City_Name    Aberdeen
# Sales           1.392
# dtype: object

# %%
#Calculating order Year from order date
dfm['Order_Year'] = dfm['Order_Date'].dt.year
dfm
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2        539  CA-2012-134894 2012-12-07 2012-12-11  Standard Class
# 3        540  CA-2012-134894 2012-12-07 2012-12-11  Standard Class
# 4        997  CA-2012-162537 2012-10-28 2012-11-03  Standard Class
# ...      ...             ...        ...        ...             ...
# 9980    4366  CA-2014-111332 2014-05-21 2014-05-23    Second Class
# 9981    4367  CA-2014-111332 2014-05-21 2014-05-23    Second Class
# 9982    7485  CA-2014-135111 2014-12-29 2015-01-03  Standard Class
# 9983    7486  CA-2014-135111 2014-12-29 2015-01-03  Standard Class
# 9984    5870  CA-2013-152247 2013-11-08 2013-11-13  Standard Class
#
#      Customer_ID       Customer_Name      Segment        Country City_Code  \
# 0       CG-12520         Claire Gute     Consumer  United States      C259
# 1       CG-12520         Claire Gute     Consumer  United States      C259
# 2       DK-12985      Darren Koutras     Consumer  United States      C259
# 3       DK-12985      Darren Koutras     Consumer  United States      C259
# 4       RD-19585            Rob Dowd     Consumer  United States      C259
# ...          ...                 ...          ...            ...       ...
# 9980    NC-18340         Nat Carroll     Consumer  United States      C418
# 9981    NC-18340         Nat Carroll     Consumer  United States      C418
# 9982    CS-12400  Christopher Schild  Home Office  United States      C418
# 9983    CS-12400  Christopher Schild  Home Office  United States      C418
# 9984    MA-17995     Michelle Arnett  Home Office  United States      C604
#
#       ... Sub-Category                                       Product_Name  \
# 0     ...    Bookcases                  Bush Somerset Collection Bookcase
# 1     ...       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2     ...   Appliances    Eureka The Boss Cordless Rechargeable Stick Vac
# 3     ...       Chairs         Situations Contoured Folding Chairs, 4/Set
# 4     ...    Envelopes                 Laser & Ink Jet Business Envelopes
# ...   ...          ...                                                ...
# 9980  ...    Fasteners                                            Staples
# 9981  ...          Art  Binney & Smith inkTank Desk Highlighter, Chise...
# 9982  ...          Art                            Staples in misc. colors
# 9983  ...      Binders                        Wilson Jones Impact Binders
# 9984  ...       Chairs      Global Troy Executive Leather Low-Back Tilter
#
#          Sales Quantity Discount    Profit  Duration  City_Name         State  \
# 0      261.960        2      0.0   41.9136    3 days  Henderson      Kentucky
# 1      731.940        3      0.0  219.5820    3 days  Henderson      Kentucky
# 2      152.940        3      0.0   41.2938    4 days  Henderson      Kentucky
# 3      283.920        4      0.0   70.9800    4 days  Henderson      Kentucky
# 4       10.670        1      0.0    4.9082    6 days  Henderson      Kentucky
# ...        ...      ...      ...       ...       ...        ...           ...
# 9980     7.410        3      0.0    3.4827    2 days      Fargo  North Dakota
# 9981    21.500       10      0.0    7.0950    2 days      Fargo  North Dakota
# 9982     2.480        1      0.0    0.8680    5 days      Fargo  North Dakota
# 9983    25.900        5      0.0   12.6910    5 days      Fargo  North Dakota
# 9984  1603.136        4      0.2  100.1960    5 days   Cheyenne       Wyoming
#
#       Order_Year
# 0           2013
# 1           2013
# 2           2012
# 3           2012
# 4           2012
# ...          ...
# 9980        2014
# 9981        2014
# 9982        2014
# 9983        2014
# 9984        2013
#
# [9985 rows x 24 columns]

# %%
#Max Sales per year.
Max_Sales_Year = dfm.groupby(['Order_Year'], as_index = False)['Sales'].sum()
Max_Sales_Year
# Out:
#    Order_Year        Sales
# 0        2011  482898.9501
# 1        2012  470524.4930
# 2        2013  605545.9900
# 3        2014  733947.0232

# %%
Max_Duration = dfm['Duration'].max()
Max_Days_Info = dfm.loc[dfm['Duration'] == Max_Duration]
Max_Days_Info.describe()
# Out:
#             Row_ID   Postal_Code         Sales    Quantity    Discount  \
# count   621.000000    621.000000    621.000000  621.000000  621.000000
# mean   5132.710145  58313.990338    265.213769    3.879227    0.160709
# std    2797.138287  32378.978326    893.824398    2.206275    0.214425
# min       4.000000   1841.000000      2.200000    1.000000    0.000000
# 25%    2996.000000  30318.000000     18.336000    2.000000    0.000000
# 50%    5450.000000  60623.000000     51.312000    3.000000    0.200000
# 75%    7464.000000  90032.000000    212.940000    5.000000    0.200000
# max    9876.000000  99301.000000  17499.950000   14.000000    0.800000
#
#             Profit         Duration   Order_Year
# count   621.000000              621   621.000000
# mean     32.740494  7 days 00:00:00  2012.753623
# std     469.823697  0 days 00:00:00     1.108111
# min   -6599.978000  7 days 00:00:00  2011.000000
# 25%       1.600800  7 days 00:00:00  2012.000000
# 50%       9.331200  7 days 00:00:00  2013.000000
# 75%      27.504000  7 days 00:00:00  2014.000000
# max    8399.976000  7 days 00:00:00  2014.000000

# %%
Min_Duration = dfm['Duration'].min()
Min_Days_Info = dfm.loc[dfm['Duration'] == Min_Duration]
Min_Days_Info.describe()
# Out:
#             Row_ID   Postal_Code        Sales    Quantity    Discount  \
# count   518.000000    518.000000   518.000000  518.000000  518.000000
# mean   5117.795367  56114.961390   235.729210    3.588803    0.152220
# std    2684.975107  31239.623812   550.033229    2.136274    0.199443
# min     367.000000   1841.000000     0.556000    1.000000    0.000000
# 25%    2866.250000  30080.000000    17.002500    2.000000    0.000000
# 50%    5127.500000  53209.000000    55.976000    3.000000    0.200000
# 75%    7267.750000  90032.000000   211.695500    5.000000    0.200000
# max    9964.000000  98115.000000  7999.980000   14.000000    0.800000
#
#             Profit         Duration   Order_Year
# count   518.000000              518   518.000000
# mean     27.878344  0 days 00:00:00  2012.791506
# std     228.289861  0 days 00:00:00     1.083981
# min   -3839.990400  0 days 00:00:00  2011.000000
# 25%       2.111650  0 days 00:00:00  2012.000000
# 50%       8.023000  0 days 00:00:00  2013.000000
# 75%      31.373300  0 days 00:00:00  2014.000000
# max    2229.024000  0 days 00:00:00  2014.000000

# %%
#Week Days the most number of orders are placed

# %%
from datetime import date
import calendar
dfm['WeekDay'] = dfm['Order_Date'].dt.day_name()
dfm
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2        539  CA-2012-134894 2012-12-07 2012-12-11  Standard Class
# 3        540  CA-2012-134894 2012-12-07 2012-12-11  Standard Class
# 4        997  CA-2012-162537 2012-10-28 2012-11-03  Standard Class
# ...      ...             ...        ...        ...             ...
# 9980    4366  CA-2014-111332 2014-05-21 2014-05-23    Second Class
# 9981    4367  CA-2014-111332 2014-05-21 2014-05-23    Second Class
# 9982    7485  CA-2014-135111 2014-12-29 2015-01-03  Standard Class
# 9983    7486  CA-2014-135111 2014-12-29 2015-01-03  Standard Class
# 9984    5870  CA-2013-152247 2013-11-08 2013-11-13  Standard Class
#
#      Customer_ID       Customer_Name      Segment        Country City_Code  \
# 0       CG-12520         Claire Gute     Consumer  United States      C259
# 1       CG-12520         Claire Gute     Consumer  United States      C259
# 2       DK-12985      Darren Koutras     Consumer  United States      C259
# 3       DK-12985      Darren Koutras     Consumer  United States      C259
# 4       RD-19585            Rob Dowd     Consumer  United States      C259
# ...          ...                 ...          ...            ...       ...
# 9980    NC-18340         Nat Carroll     Consumer  United States      C418
# 9981    NC-18340         Nat Carroll     Consumer  United States      C418
# 9982    CS-12400  Christopher Schild  Home Office  United States      C418
# 9983    CS-12400  Christopher Schild  Home Office  United States      C418
# 9984    MA-17995     Michelle Arnett  Home Office  United States      C604
#
#       ...                                       Product_Name     Sales  \
# 0     ...                  Bush Somerset Collection Bookcase   261.960
# 1     ...  Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.940
# 2     ...    Eureka The Boss Cordless Rechargeable Stick Vac   152.940
# 3     ...         Situations Contoured Folding Chairs, 4/Set   283.920
# 4     ...                 Laser & Ink Jet Business Envelopes    10.670
# ...   ...                                                ...       ...
# 9980  ...                                            Staples     7.410
# 9981  ...  Binney & Smith inkTank Desk Highlighter, Chise...    21.500
# 9982  ...                            Staples in misc. colors     2.480
# 9983  ...                        Wilson Jones Impact Binders    25.900
# 9984  ...      Global Troy Executive Leather Low-Back Tilter  1603.136
#
#      Quantity Discount    Profit Duration  City_Name         State  \
# 0           2      0.0   41.9136   3 days  Henderson      Kentucky
# 1           3      0.0  219.5820   3 days  Henderson      Kentucky
# 2           3      0.0   41.2938   4 days  Henderson      Kentucky
# 3           4      0.0   70.9800   4 days  Henderson      Kentucky
# 4           1      0.0    4.9082   6 days  Henderson      Kentucky
# ...       ...      ...       ...      ...        ...           ...
# 9980        3      0.0    3.4827   2 days      Fargo  North Dakota
# 9981       10      0.0    7.0950   2 days      Fargo  North Dakota
# 9982        1      0.0    0.8680   5 days      Fargo  North Dakota
# 9983        5      0.0   12.6910   5 days      Fargo  North Dakota
# 9984        4      0.2  100.1960   5 days   Cheyenne       Wyoming
#
#       Order_Year    WeekDay
# 0           2013   Saturday
# 1           2013   Saturday
# 2           2012     Friday
# 3           2012     Friday
# 4           2012     Sunday
# ...          ...        ...
# 9980        2014  Wednesday
# 9981        2014  Wednesday
# 9982        2014     Monday
# 9983        2014     Monday
# 9984        2013     Friday
#
# [9985 rows x 25 columns]

# %%
weekday_sales = dfm.groupby(['WeekDay'], as_index = False)['Sales'].sum()
weekday_sales
# Out:
#      WeekDay        Sales
# 0     Friday  450077.3347
# 1     Monday  408529.0943
# 2   Saturday  223176.0364
# 3     Sunday   41928.6428
# 4   Thursday  415264.7249
# 5    Tuesday  413430.6073
# 6  Wednesday  340510.0159

# %%
dfm['Customer_Name'].value_counts()
# Out:
# William Brown        37
# Matt Abelman         34
# Paul Prost           34
# John Lee             34
# Jonathan Doherty     32
#                      ..
# Lela Donovan          1
# Ricardo Emerson       1
# Jocasta Rupert        1
# Carl Jackson          1
# Anthony O'Donnell     1
# Name: Customer_Name, Length: 793, dtype: int64
